# %% [markdown]
# ## PROJECT 2: TBD
# ###22.05.05
#
# Jonathan Jones

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/Week 7/Memphis TN Residential RE data.xlsx'
df = pd.read_excel(filename)
df.head()
# Out:
#                                Region Month of Period End  Median Sale Price  \
# 0  Memphis, TN - 35th Ward Civic Club            May 2013            13000.0
# 1                                 NaN           June 2013            13000.0
# 2                                 NaN           July 2013            13000.0
# 3                                 NaN          April 2014             3500.0
# 4                                 NaN            May 2014             4750.0
#
#    Median Sale Price MoM   Median Sale Price YoY   Homes Sold  \
# 0                     NaN                     NaN           1
# 1                0.000000                     NaN           1
# 2                0.000000                     NaN           1
# 3                     NaN                     NaN           1
# 4                0.357143               -0.634615           2
#
#    Homes Sold MoM   Homes Sold YoY   New Listings  New Listings MoM   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23973 entries, 0 to 23972
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Region                     227 non-null    object
#  1   Month of Period End        23973 non-null  object
#  2   Median Sale Price          23973 non-null  float64
#  3   Median Sale Price MoM      23093 non-null  float64
#  4   Median Sale Price YoY      22017 non-null  float64
#  5   Homes Sold                 23973 non-null  int64
#  6   Homes Sold MoM             23093 non-null  float64
#  7   Homes Sold YoY             22017 non-null  float64
#  8   New Listings               22972 non-null  float64
#  9   New Listings MoM           21909 non-null  float64
#  10  New Listings YoY           20793 non-null  float64
#  11  Inventory                  15615 non-null  float64
#  12  Inventory MoM              14645 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 109

# %% [markdown]
# 1) Source of data
#   https://www.redfin.com/news/data-center/
#
# 2) Brief description of data
#   Housing market data for the city of Memphis, TN and surrounding area
#
# 3) What is the target?
#
#   Predicting the Days on the Market.
#
# 4) Is this a classification or regression problem?
#   This is regression problem as the target value is not limited to a finite number of classes or values.
#
# 5) How many features?
#
#   20-2(target & region) columns = 18 features.
#
# 6) How many rows of data.
#
#   23973
#
# 7) What, if any, challenges do you foresee in cleaning, exploring, or modeling with this dataset?
#
#   I can already see that there are multiple duplicated rows (109) and numerous missing entries. I am concerned that there may not be enough data to build an accurate model.

# %%
filename2 = '/content/drive/MyDrive/Colab Notebooks/Week 7/Orange County FL_ Housing Data.xlsx'
df2= pd.read_excel(filename2)
df2.head()
# Out:
#   Month of Period End  Median Sale Price  Median Sale Price MoM   \
# 0       February 2012           198000.0                0.389474
# 1          March 2012           110000.0               -0.444444
# 2          April 2012            71000.0               -0.354545
# 3            May 2012            92000.0                0.295775
# 4           June 2012            72600.0               -0.210870
#
#    Median Sale Price YoY   Homes Sold  Homes Sold MoM   Homes Sold YoY   \
# 0                1.134771           2         1.000000        -0.333333
# 1               -0.043478           7         2.500000        -0.222222
# 2                0.028986           1        -0.857143        -0.857143
# 3                0.022222           7         6.000000        -0.363636
# 4               -0.308571           5        -0.285714         0.000000
#
#    New Listings  New Listings MoM   New Listings YoY   ...  Inventory MoM   \
# ...

# %%
df2.shape
# Out:
# (122, 21)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isna().sum()
# Out:
# Month of Period End            0
# Median Sale Price              0
# Median Sale Price MoM          0
# Median Sale Price YoY          0
# Homes Sold                     0
# Homes Sold MoM                 0
# Homes Sold YoY                 0
# New Listings                   0
# New Listings MoM               0
# New Listings YoY               0
# Inventory                      0
# Inventory MoM                  0
#  Inventory YoY                 0
# Days on Market                 0
# Days on Market MoM             0
# Days on Market YoY             0
# Average Sale To List           0
# Average Sale To List MoM       0
# Average Sale To List YoY       0
# Unnamed: 19                  122
# Fed Funds Effective Rate      33
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month of Period End        122 non-null    object
#  1   Median Sale Price          122 non-null    float64
#  2   Median Sale Price MoM      122 non-null    float64
#  3   Median Sale Price YoY      122 non-null    float64
#  4   Homes Sold                 122 non-null    int64
#  5   Homes Sold MoM             122 non-null    float64
#  6   Homes Sold YoY             122 non-null    float64
#  7   New Listings               122 non-null    int64
#  8   New Listings MoM           122 non-null    float64
#  9   New Listings YoY           122 non-null    float64
#  10  Inventory                  122 non-null    int64
#  11  Inventory MoM              122 non-null    float64
#  12   Inventory YoY             122 non-null    float64
# ...

# %%
df2.drop(columns = 'Unnamed: 19', inplace=True)

df2.info()

# %%
df2['Fed Funds Effective Rate'].fillna(method = 'ffill', inplace=True)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month of Period End        122 non-null    object
#  1   Median Sale Price          122 non-null    float64
#  2   Median Sale Price MoM      122 non-null    float64
#  3   Median Sale Price YoY      122 non-null    float64
#  4   Homes Sold                 122 non-null    int64
#  5   Homes Sold MoM             122 non-null    float64
#  6   Homes Sold YoY             122 non-null    float64
#  7   New Listings               122 non-null    int64
#  8   New Listings MoM           122 non-null    float64
#  9   New Listings YoY           122 non-null    float64
#  10  Inventory                  122 non-null    int64
#  11  Inventory MoM              122 non-null    float64
#  12   Inventory YoY             122 non-null    float64
# ...

# %%
df2.describe().round(2)
# Out:
#        Median Sale Price  Median Sale Price MoM   Median Sale Price YoY   \
# count             122.00                  122.00                  122.00
# mean           230491.14                    0.06                    0.19
# std             92960.54                    0.34                    0.40
# min             71000.00                   -0.66                   -0.51
# 25%            155672.50                   -0.16                   -0.09
# 50%            222250.00                    0.01                    0.12
# 75%            296150.00                    0.25                    0.39
# max            510000.00                    1.39                    1.83
#
#        Homes Sold  Homes Sold MoM   Homes Sold YoY   New Listings  \
# count      122.00           122.00           122.00        122.00
# mean         9.23             0.23             0.44         12.57
# std          4.41             0.86             1.07          5.29
# ...

# %% [markdown]
# VISUAL ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation = df2.corr()

fig, HM = plt.subplots(nrows=1, ncols=1, figsize=(16,16));
HM = sns.heatmap(correlation, cmap = 'rocket_r', annot=True);
HM.set_title('Correlation Heatmap\n', fontsize=20);

# %% [markdown]
# This is a similar dataset centered around Orange County Florida where the city of Orlando is.
#
# 1) Source of data
#   https://www.redfin.com/news/data-center/
#
# 2) Brief description of data
#   Housing market data for the city of Orlando, FL and surrounding area
#
# 3) What is the target?
#
#   Predicting the Days on the Market.
#
# 4) Is this a classification or regression problem?
#
#   This is regression problem as the target value is not limited to a finite number of classes or values.
#
# 5) How many features?
#
#   21-1(target) columns = 20 features.
#
# 6) How many rows of data.
#
#   122
#
# 7) What, if any, challenges do you foresee in cleaning, exploring, or modeling with this dataset?
#
#   There is not enough data in this set. 122 rows would be ok for visual analysis but I anticipate that there would be significant issues with fitting a model.
#
#
#   I am still searching for a viable dataset. County and city websites for regions that I am interested in have condensed data sets. An MLS database would be ideal, so that can control the numbers of rows and columns that go into the dataframe.
